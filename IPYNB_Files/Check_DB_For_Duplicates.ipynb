# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import dns
from dns import resolver 

pd.set_option('display.max_colwidth', None)

client = pymongo.MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")

# %%
mongo_db = client["Tweets_DB"]
mongo_collection = mongo_db["Tweets_v2"]

# %%
tweets_df = pd.DataFrame(list(mongo_collection.find()))

# %%
print("tweets_df: " + str(len(tweets_df)))
# Out:
# tweets_df: 162737

# %%
dupe_df = tweets_df[tweets_df.duplicated(['Tweet Id'],keep="first")]
print("dupe_df: " + str(len(dupe_df)))
# Out:
# dupe_df: 10020

# %%
DupeList = dupe_df['_id']

# %%
for RecordToDelete in DupeList:
    result = mongo_collection.delete_one( { "_id": RecordToDelete } )
    print(result)
# Out:
# ...
# ...
# ...

# %%
tweets_df2 = pd.DataFrame(list(mongo_collection.find()))
print(len(tweets_df2))
# Out:
# 152717
