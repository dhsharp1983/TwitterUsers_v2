# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import dns
from dns import resolver 

pd.set_option('display.max_colwidth', None)

client = pymongo.MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")
mongo_db = client["Tweets_DB"]
mongo_collection = mongo_db["Users_Table"]

# %%
QueryIdentity = "Donald J. Trump"
users_df = pd.DataFrame(list(mongo_collection.find( {"Identity": QueryIdentity} )))
users_df.head()

# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import dns
from dns import resolver 

import wikipedia

pd.set_option('display.max_colwidth', None)

client = pymongo.MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")
mongo_db = client["Tweets_DB"]
mongo_collection = mongo_db["Users_Table"]

users_df = pd.DataFrame(list(mongo_collection.find(  )))

users_df
# Out:
#                          _id  index                   name  \
# 0   60eed4f6060d3647c22b47fb      0         "Akshay Kumar"
# 1   60eed4f6060d3647c22b47fc      1     "Amitabh Bachchan"
# 2   60eed4f6060d3647c22b47fd      2        "Ariana Grande"
# 3   60eed4f6060d3647c22b47fe      3         "Barack Obama"
# 4   60eed4f6060d3647c22b47ff      4    "BBC Breaking News"
# 5   60eed4f6060d3647c22b4800      5           "Bill Gates"
# 6   60eed4f6060d3647c22b4801      6       "Britney Spears"
# 7   60eed4f6060d3647c22b4802      7           "Bruno Mars"
# 8   60eed4f6060d3647c22b4803      8                  "CNN"
# 9   60eed4f6060d3647c22b4804      9    "CNN Breaking News"
# 10  60eed4f6060d3647c22b4805     10    "Cristiano Ronaldo"
# 11  60eed4f6060d3647c22b4806     11      "Donald J. Trump"
# 12  60eed4f6060d3647c22b4807     12               "Drizzy"
# 13  60eed4f6060d3647c22b4808     13      "Ellen DeGeneres"
# 14  60eed4f6060d3647c22b4809     14                 "ESPN"
# ...

# %%
def GetWikiSummary(InputUser):
    UserSummary = wikipedia.summary(InputUser, sentences=3)
    return UserSummary
        
# exploded_group_df.reset_index(inplace = True)
users_with_wiki_df = users_df['WikiSummary'] = users_df['name'].apply(GetWikiSummary)
users_with_wiki_df
# Out:
# ---------------------------------------------------------------------------
# WikipediaException                        Traceback (most recent call last)
# <ipython-input-5-85435039f4a6> in <module>
#       4
#       5 # exploded_group_df.reset_index(inplace = True)
# ----> 6 users_with_wiki_df = users_df['WikiSummary'] = users_df['name'].apply(GetWikiSummary)
#       7 users_with_wiki_df
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-5-85435039f4a6> in GetWikiSummary(InputUser)
#       1 def GetWikiSummary(InputUser):
# ----> 2     UserSummary = wikipedia.summary(InputUser, sentences=3)
# ...
