# %%
import pymongo
from pymongo import MongoClient
import os
from os import listdir
import pandas as pd
import re
import glob
import sys

pd.set_option('display.max_colwidth', None)

# %%
# Read Previous Database into DF

client = pymongo.MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")
mongo_db = client["Tweets_DB"]
mongo_collection = mongo_db["Combined_Tweets"]


tweets_df = pd.DataFrame(list(mongo_collection.find()))
tweets_df.head()
# Out:
#                         _id  level_0  index               Tweet Id  \
# 0  60be2af24a7a5d65a6b422e1       54     54  "1209691918445080576"
# 1  60be2af24a7a5d65a6b422b5       10     10  "1213014776369934336"
# 2  60be2af24a7a5d65a6b422fc       81     81  "1207994673781858305"
# 3  60be2af24a7a5d65a6b42331      134    134  "1201355151186911232"
# 4  60be2af24a7a5d65a6b42338      141    141  "1200063604353110017"
#
#                    Name      Username Gender       Vocation  \
# 0        "Akshay Kumar"   akshaykumar   Male  Entertainment
# 1        "Akshay Kumar"   akshaykumar   Male  Entertainment
# 2  "Dharma Productions"  dharmamovies   Male  Entertainment
# 3        "Akshay Kumar"   akshaykumar   Male  Entertainment
# 4        "Akshay Kumar"   akshaykumar   Male  Entertainment
#
#                                                                 Hashtags(#)  \
# 0                   ['#MerryChristmas', '#GoodNewwz', '#KareenaKapoorKhan']
# ...

# %%
identity_group_df = tweets_df.groupby("Identity")

# %%
identity_group_count_df = identity_group_df.count()
identity_group_sum_df = identity_group_df.sum()
identity_group_avg_df = identity_group_df.mean()
# identity_group_min_df = identity_group_df.min()
# identity_group_max_df = identity_group_df.max()

# %%
identity_group_sum_df
# Out:
#                      level_0    index  Total #  Total @
# Identity
# Akshay Kumar         5192253  5192253     3231     5110
# Amitabh Bachchan    19213338  7081966     1055     5203
# Ariana Grande       27977139  5276376      185     2367
# BBC                 48728295  5227761      779      137
# Barack Obama        38075245  5166505     1826      537
# Bill Gates          59505875  5279625      922     1568
# Britney Spears      72065940  5562780     1854     2276
# Bruno Mars          79982770  5166505     1004     1413
# CNN                101594460  5263390      135      288
# CNN Breaking        89873600  5118400      148        5
# Cristiano Ronaldo  116472745  5659930     1498     1563
# Donald Trump       124468016  5380840      779     1797
# Drake               70955439  1537381      224      722
# ESPN               143889711  5596185      362     1886
# FC Barcelona       161240499  6032601     1985     2117
# Harry Styles       159252951  5121600      177     1840
# ...

# %%
tweets_df.dtypes
# Out:
# _id            object
# level_0         int64
# index           int64
# Tweet Id       object
# Name           object
# Username       object
# Gender         object
# Vocation       object
# Hashtags(#)    object
# Total #         int64
# Mentions(@)    object
# Total @         int64
# Likes          object
# Retweets       object
# Images         object
# Videos         object
# Date           object
# Time           object
# Identity       object
# dtype: object

# %%
pd.to_numeric(tweets_df['Likes'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string ""salad""
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-8288ccb493bb> in <module>
# ----> 1 pd.to_numeric(tweets_df['Likes'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     150         coerce_numeric = errors not in ("ignore", "raise")
#     151         try:
# --> 152             values = lib.maybe_convert_numeric(
#     153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string ""salad"" at position 151085

# %%
client = pymongo.MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")
mongo_db = client["Tweets_DB"]
mongo_collection = mongo_db["Tweets_v2"]

tweets_df = pd.DataFrame(list(mongo_collection.find()))
tweets_df.head()
# Out:
#                         _id  index               Tweet Id            Name  \
# 0  60e6c7c6e59504fac2ad5abb      0  "1220262518519521281"  "Akshay Kumar"
# 1  60e6c7c6e59504fac2ad5abc      1  "1220236816604749824"  "Akshay Kumar"
# 2  60e6c7c6e59504fac2ad5abd      2  "1219804361133477890"  "Akshay Kumar"
# 3  60e6c7c6e59504fac2ad5abe      3  "1219491375793635329"  "Akshay Kumar"
# 4  60e6c7c6e59504fac2ad5abf      4  "1219156453354655745"  "Akshay Kumar"
#
#       Username  \
# 0  akshaykumar
# 1  akshaykumar
# 2  akshaykumar
# 3  akshaykumar
# 4  akshaykumar
#
#                                                                                                                                                                                                                                                                                           Tweet Content  \
# ...
