# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import dns
from dns import resolver 

pd.set_option('display.max_colwidth', None)
client = pymongo.MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")

# %%
mongo_testdb = client["testDB"]
mongo_test_collection = mongo_testdb["test_sentiment"]

test_df = pd.DataFrame(list(mongo_test_collection.find()))
test_df
# Out:
#                           _id  level_0  index               Tweet Id  \
# 0    60e6c7c6e59504fac2adf633        0  39800  "1220109701276454922"
# 1    60e6c7c6e59504fac2adf634        1  39801  "1220107185276907521"
# 2    60e6c7c6e59504fac2adf635        2  39802  "1220105021930426368"
# 3    60e6c7c6e59504fac2adf636        3  39803  "1220103850482380802"
# 4    60e6c7c6e59504fac2adf637        4  39804  "1220101014734475265"
# ..                        ...      ...    ...                    ...
# 195  60e6c7c6e59504fac2adf6f6      195  39995  "1218190672064319488"
# 196  60e6c7c6e59504fac2adf6f7      196  39996  "1218174158280019968"
# 197  60e6c7c6e59504fac2adf6f8      197  39997  "1218165916451602432"
# 198  60e6c7c6e59504fac2adf6f9      198  39998  "1218164681464000513"
# 199  60e6c7c6e59504fac2adf6fa      199  39999  "1218164357395374081"
#
#                                   Name         Username  \
# 0              "Sen. Marsha Blackburn"  marshablackburn
# ...

# %%
test_df.rename(columns={"Tweet Content": "TweetContent"}, inplace=True)
test_df
# Out:
#                           _id  level_0  index               Tweet Id  \
# 0    60e6c7c6e59504fac2adf633        0  39800  "1220109701276454922"
# 1    60e6c7c6e59504fac2adf634        1  39801  "1220107185276907521"
# 2    60e6c7c6e59504fac2adf635        2  39802  "1220105021930426368"
# 3    60e6c7c6e59504fac2adf636        3  39803  "1220103850482380802"
# 4    60e6c7c6e59504fac2adf637        4  39804  "1220101014734475265"
# ..                        ...      ...    ...                    ...
# 195  60e6c7c6e59504fac2adf6f6      195  39995  "1218190672064319488"
# 196  60e6c7c6e59504fac2adf6f7      196  39996  "1218174158280019968"
# 197  60e6c7c6e59504fac2adf6f8      197  39997  "1218165916451602432"
# 198  60e6c7c6e59504fac2adf6f9      198  39998  "1218164681464000513"
# 199  60e6c7c6e59504fac2adf6fa      199  39999  "1218164357395374081"
#
#                                   Name         Username  \
# 0              "Sen. Marsha Blackburn"  marshablackburn
# ...
